# %% [markdown]
# <a href="https://colab.research.google.com/github/Kushagragoel-code/data-science/blob/main/DAY_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
  return a+b
print(add(4,5))
# Out:
# 9

# %%
x=lambda a,b: b *a
print(x(6,7))
# Out:
# 42

# %%
st =""
print(len(st))
st="treee trefd trew"
t=st.upper()
print(t)
k = st.title()
print(k)
m=st.capitalize()
print(m)
# Out:
# 0
# TREEE TREFD TREW
# Treee Trefd Trew
# Treee trefd trew

# %%
st = " Kushagra Goel "
print(st)
st = st.strip()
print(st)
# Out:
#  Kushagra Goel
# Kushagra Goel

# %%
st = "kushagra"
sp = "goel"
print(st+sp)
# Out:
# kushagragoel

# %%
a=" today "
b = "  weather"
c = "is GooD"
a=a.strip()
b=b.strip()

c=c.strip()
st = a+" "+b+" "+c
st = st.capitalize()
print(st)
st=st.replace("good","bad")
print(st)
# Out:
# Today weather is good
# Today weather is bad

# %%
st = "today weather is good"
print(st.find("good"))
i = st.find("today")
print(i)
o = st.find("is")
print(o)
y = st.find("weather")
print(y)
u = st.startswith("today")
print(u)
u = st.endswith("good")
print(u)
tu= sorted(st)
print(tu)
# Out:
# 17
# 0
# 14
# 6
# True
# True
# [' ', ' ', ' ', 'a', 'a', 'd', 'd', 'e', 'e', 'g', 'h', 'i', 'o', 'o', 'o', 'r', 's', 't', 't', 'w', 'y']

# %%
s = "hello world"
print(s[6:11])
# Out:
# world

# %%
st = {2,2,3,23,1,2}
st.add(0)
print(st)
# Out:
# {0, 1, 2, 3, 23}

# %%
dct = {
    "name":[ "rakesh","skdslkd" , "fjdkds"] ,
    "age" : 20 ,
    "occupation" : "tech" ,
    "roll no. "  :26 ,

}

print(dct)
print(dct["name"])
print(dct["name"][1])
print(dct["age"])
print(dct["occupation"])
print(dct["roll no. "])


dct['id'] = 12
print(dct)


del dct["name"]
print(dct)
# Out:
# {'name': ['rakesh', 'skdslkd', 'fjdkds'], 'age': 20, 'occupation': 'tech', 'roll no. ': 26}
# ['rakesh', 'skdslkd', 'fjdkds']
# skdslkd
# 20
# tech
# 26
# {'name': ['rakesh', 'skdslkd', 'fjdkds'], 'age': 20, 'occupation': 'tech', 'roll no. ': 26, 'id': 12}
# {'age': 20, 'occupation': 'tech', 'roll no. ': 26, 'id': 12}
